# %%
print('Hello World')
# Out:
# Hello World

# %%
s = 3
t = 2
s*t
# Out:
# 6

# %%
s = 3
t = 6

s/t
# Out:
# 0.5

# %%
import numpy
import pandas
# %matplotlib inline
import matplotlib.pylab as plt

# %%
plt.p([3,2,5], [1,2,3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-1e8a3ee78671> in <module>
# ----> 1 plt.p([3,2,5], [1,2,3])
#
# AttributeError: module 'matplotlib.pylab' has no attribute 'p'

# %%
plt.plot([3,2,5], [1,2,3])

# %%
plt.scatter([3,2,5], [1,2,3])

# %%
s = 12
T = 10
S*T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9fcea112f279> in <module>
#       1 s = 12
#       2 T = 10
# ----> 3 S*T
#
# NameError: name 'S' is not defined

# %%
S = 12
T = 10
S*T
# Out:
# 120

# %%
import numpy
import pandas
# %matplotlib inline
import matplotlib.pylab as plt

# %%
plt.plot([17,12,15], [11,10,13])

# %%
plt.scatter([17,12,15], [11,10,13])

# %% [markdown]
# # Heading
# This is a text cell
